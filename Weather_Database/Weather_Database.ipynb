# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# print(cities)

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

# Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

# Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_condition = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_condition,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | zheshart
# Processing Record 2 of Set 1 | anshun
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | socorro
# Processing Record 6 of Set 1 | wuwei
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | noumea
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | bubaque
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | airai
# Processing Record 16 of Set 1 | goundam
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | ponta do sol
# Processing Record 19 of Set 1 | macaboboni
# City not found. Skipping...
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | esperance
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | bethel
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | caravelas
# Processing Record 30 of Set 1 | anadyr
# Processing Record 31 of Set 1 | clyde river
# Processing Record 32 of Set 1 | utrecht
# Processing Record 33 of Set 1 | newport
# Processing Record 34 of Set 1 | constantine
# Processing Record 35 of Set 1 | codrington
# Processing Record 36 of Set 1 | kiwira
# Processing Record 37 of Set 1 | grand gaube
# Processing Record 38 of Set 1 | victoria
# Processing Record 39 of Set 1 | hofn
# Processing Record 40 of Set 1 | vanavara
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | tucuman
# Processing Record 43 of Set 1 | litoral del san juan
# City not found. Skipping...
# Processing Record 44 of Set 1 | les cayes
# Processing Record 45 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 1 | yakeshi
# Processing Record 47 of Set 1 | narsaq
# Processing Record 48 of Set 1 | komsomolskiy
# Processing Record 49 of Set 1 | pemangkat
# Processing Record 50 of Set 1 | ribeira grande
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | tongliao
# Processing Record 3 of Set 2 | luderitz
# Processing Record 4 of Set 2 | palencia
# Processing Record 5 of Set 2 | katsuura
# Processing Record 6 of Set 2 | adrar
# Processing Record 7 of Set 2 | nemuro
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | roald
# Processing Record 10 of Set 2 | shelburne
# Processing Record 11 of Set 2 | lasa
# Processing Record 12 of Set 2 | ekhabi
# Processing Record 13 of Set 2 | muros
# Processing Record 14 of Set 2 | hasaki
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | hearst
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | coquimbo
# Processing Record 19 of Set 2 | fortuna
# Processing Record 20 of Set 2 | torbat-e jam
# Processing Record 21 of Set 2 | sume
# Processing Record 22 of Set 2 | zhuhai
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | malkangiri
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | hobart
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | comodoro rivadavia
# Processing Record 33 of Set 2 | busselton
# Processing Record 34 of Set 2 | marshall
# Processing Record 35 of Set 2 | cherskiy
# Processing Record 36 of Set 2 | kaitangata
# Processing Record 37 of Set 2 | port lincoln
# Processing Record 38 of Set 2 | tocopilla
# Processing Record 39 of Set 2 | kloulklubed
# Processing Record 40 of Set 2 | sao filipe
# Processing Record 41 of Set 2 | namibe
# Processing Record 42 of Set 2 | nanortalik
# Processing Record 43 of Set 2 | pavlovka
# Processing Record 44 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 2 | atambua
# Processing Record 46 of Set 2 | kapit
# Processing Record 47 of Set 2 | babu
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | policoro
# Processing Record 50 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | deputatskiy
# Processing Record 3 of Set 3 | havoysund
# Processing Record 4 of Set 3 | zlobin
# Processing Record 5 of Set 3 | ulagan
# Processing Record 6 of Set 3 | synya
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | georgetown
# Processing Record 9 of Set 3 | vaini
# Processing Record 10 of Set 3 | lompoc
# Processing Record 11 of Set 3 | cidreira
# Processing Record 12 of Set 3 | fort nelson
# Processing Record 13 of Set 3 | gat
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | hermanus
# Processing Record 16 of Set 3 | jackson
# Processing Record 17 of Set 3 | urucui
# Processing Record 18 of Set 3 | saint-lo
# Processing Record 19 of Set 3 | peleduy
# Processing Record 20 of Set 3 | sola
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | sindou
# Processing Record 23 of Set 3 | mikhaylovka
# Processing Record 24 of Set 3 | los llanos de aridane
# Processing Record 25 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 3 | zhezkazgan
# Processing Record 27 of Set 3 | ormara
# Processing Record 28 of Set 3 | leshan
# Processing Record 29 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 3 | broome
# Processing Record 31 of Set 3 | cabo san lucas
# Processing Record 32 of Set 3 | carutapera
# Processing Record 33 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 3 | wagar
# Processing Record 35 of Set 3 | lorengau
# Processing Record 36 of Set 3 | kitimat
# Processing Record 37 of Set 3 | san patricio
# Processing Record 38 of Set 3 | butaritari
# Processing Record 39 of Set 3 | yar-sale
# Processing Record 40 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 41 of Set 3 | ostrovnoy
# Processing Record 42 of Set 3 | avarua
# Processing Record 43 of Set 3 | prince george
# Processing Record 44 of Set 3 | berlevag
# Processing Record 45 of Set 3 | serenje
# Processing Record 46 of Set 3 | hambantota
# Processing Record 47 of Set 3 | saint-philippe
# Processing Record 48 of Set 3 | pevek
# Processing Record 49 of Set 3 | nouakchott
# Processing Record 50 of Set 3 | kavieng
# Processing Record 1 of Set 4 | nantucket
# Processing Record 2 of Set 4 | iqaluit
# Processing Record 3 of Set 4 | tiksi
# Processing Record 4 of Set 4 | george
# Processing Record 5 of Set 4 | la ronge
# Processing Record 6 of Set 4 | divnomorskoye
# Processing Record 7 of Set 4 | opuwo
# Processing Record 8 of Set 4 | provideniya
# Processing Record 9 of Set 4 | itoman
# Processing Record 10 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 4 | vostok
# Processing Record 12 of Set 4 | taltal
# Processing Record 13 of Set 4 | xianyang
# Processing Record 14 of Set 4 | gidole
# Processing Record 15 of Set 4 | bayan
# Processing Record 16 of Set 4 | kerema
# Processing Record 17 of Set 4 | novobirilyussy
# Processing Record 18 of Set 4 | longyearbyen
# Processing Record 19 of Set 4 | hobyo
# Processing Record 20 of Set 4 | yeltsovka
# City not found. Skipping...
# Processing Record 21 of Set 4 | krasnoselkup
# Processing Record 22 of Set 4 | thompson
# Processing Record 23 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 4 | la tuque
# Processing Record 25 of Set 4 | nampula
# Processing Record 26 of Set 4 | bluefield
# Processing Record 27 of Set 4 | maceio
# Processing Record 28 of Set 4 | canete
# Processing Record 29 of Set 4 | luena
# Processing Record 30 of Set 4 | miraflores
# Processing Record 31 of Set 4 | barrow
# Processing Record 32 of Set 4 | smithers
# Processing Record 33 of Set 4 | pangnirtung
# Processing Record 34 of Set 4 | pacifica
# Processing Record 35 of Set 4 | lengshuijiang
# Processing Record 36 of Set 4 | mahebourg
# Processing Record 37 of Set 4 | port-gentil
# Processing Record 38 of Set 4 | pundaguitan
# Processing Record 39 of Set 4 | calabozo
# Processing Record 40 of Set 4 | khatanga
# Processing Record 41 of Set 4 | brest
# Processing Record 42 of Set 4 | nikolskoye
# Processing Record 43 of Set 4 | souillac
# Processing Record 44 of Set 4 | pathein
# Processing Record 45 of Set 4 | galle
# Processing Record 46 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 4 | nizwa
# Processing Record 48 of Set 4 | mayo
# Processing Record 49 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 5 | saint george
# Processing Record 2 of Set 5 | saint-augustin
# Processing Record 3 of Set 5 | bossangoa
# Processing Record 4 of Set 5 | sakti
# Processing Record 5 of Set 5 | caconda
# Processing Record 6 of Set 5 | uribia
# Processing Record 7 of Set 5 | orlik
# Processing Record 8 of Set 5 | segezha
# Processing Record 9 of Set 5 | talaya
# Processing Record 10 of Set 5 | geraldton
# Processing Record 11 of Set 5 | tabou
# Processing Record 12 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 5 | kalaleh
# Processing Record 14 of Set 5 | cockburn town
# Processing Record 15 of Set 5 | naze
# Processing Record 16 of Set 5 | wanning
# Processing Record 17 of Set 5 | conceicao do araguaia
# Processing Record 18 of Set 5 | lindas
# Processing Record 19 of Set 5 | mount gambier
# Processing Record 20 of Set 5 | redmond
# Processing Record 21 of Set 5 | makakilo city
# Processing Record 22 of Set 5 | sinnamary
# Processing Record 23 of Set 5 | guerrero negro
# Processing Record 24 of Set 5 | namatanai
# Processing Record 25 of Set 5 | palmer
# Processing Record 26 of Set 5 | alepe
# Processing Record 27 of Set 5 | arman
# Processing Record 28 of Set 5 | mayumba
# Processing Record 29 of Set 5 | lavrentiya
# Processing Record 30 of Set 5 | saskylakh
# Processing Record 31 of Set 5 | ancud
# Processing Record 32 of Set 5 | marsh harbour
# Processing Record 33 of Set 5 | nurota
# Processing Record 34 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 5 | flin flon
# Processing Record 36 of Set 5 | magaria
# Processing Record 37 of Set 5 | matiri
# Processing Record 38 of Set 5 | alofi
# Processing Record 39 of Set 5 | wieliczka
# Processing Record 40 of Set 5 | cayenne
# Processing Record 41 of Set 5 | porto velho
# Processing Record 42 of Set 5 | zhigansk
# Processing Record 43 of Set 5 | riverton
# Processing Record 44 of Set 5 | sinop
# Processing Record 45 of Set 5 | terek
# Processing Record 46 of Set 5 | vanimo
# Processing Record 47 of Set 5 | ilulissat
# Processing Record 48 of Set 5 | horta
# Processing Record 49 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 5 | huarmey
# Processing Record 1 of Set 6 | touros
# Processing Record 2 of Set 6 | la asuncion
# Processing Record 3 of Set 6 | ponazyrevo
# Processing Record 4 of Set 6 | waipawa
# Processing Record 5 of Set 6 | dahanu
# Processing Record 6 of Set 6 | nicoya
# Processing Record 7 of Set 6 | samarai
# Processing Record 8 of Set 6 | andenes
# Processing Record 9 of Set 6 | mount isa
# Processing Record 10 of Set 6 | syracuse
# Processing Record 11 of Set 6 | san lorenzo
# Processing Record 12 of Set 6 | asht
# City not found. Skipping...
# Processing Record 13 of Set 6 | port augusta
# Processing Record 14 of Set 6 | ghanzi
# Processing Record 15 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 6 | vila do maio
# Processing Record 17 of Set 6 | jamalpur
# Processing Record 18 of Set 6 | matara
# Processing Record 19 of Set 6 | yaan
# Processing Record 20 of Set 6 | ariquemes
# Processing Record 21 of Set 6 | masunga
# Processing Record 22 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 25 of Set 6 | acarau
# Processing Record 26 of Set 6 | corpus christi
# Processing Record 27 of Set 6 | coahuayana
# Processing Record 28 of Set 6 | tuatapere
# Processing Record 29 of Set 6 | polyanka
# Processing Record 30 of Set 6 | te anau
# Processing Record 31 of Set 6 | hovd
# Processing Record 32 of Set 6 | rocha
# Processing Record 33 of Set 6 | bichena
# Processing Record 34 of Set 6 | brae
# Processing Record 35 of Set 6 | praia da vitoria
# Processing Record 36 of Set 6 | kyzyl-suu
# Processing Record 37 of Set 6 | aljezur
# Processing Record 38 of Set 6 | zhangye
# Processing Record 39 of Set 6 | mouzakion
# City not found. Skipping...
# Processing Record 40 of Set 6 | charters towers
# Processing Record 41 of Set 6 | wau
# Processing Record 42 of Set 6 | norton
# Processing Record 43 of Set 6 | texarkana
# Processing Record 44 of Set 6 | henties bay
# Processing Record 45 of Set 6 | mecca
# Processing Record 46 of Set 6 | charcas
# Processing Record 47 of Set 6 | tombouctou
# Processing Record 48 of Set 6 | boksitogorsk
# Processing Record 49 of Set 6 | youkounkoun
# Processing Record 50 of Set 6 | porto novo
# Processing Record 1 of Set 7 | arraial do cabo
# Processing Record 2 of Set 7 | kisangani
# Processing Record 3 of Set 7 | daru
# Processing Record 4 of Set 7 | mahibadhoo
# Processing Record 5 of Set 7 | pirgos
# Processing Record 6 of Set 7 | dubuque
# Processing Record 7 of Set 7 | half moon bay
# Processing Record 8 of Set 7 | tripoli
# Processing Record 9 of Set 7 | hami
# Processing Record 10 of Set 7 | yakima
# Processing Record 11 of Set 7 | lampazos de naranjo
# Processing Record 12 of Set 7 | camacha
# Processing Record 13 of Set 7 | norman wells
# Processing Record 14 of Set 7 | beloha
# Processing Record 15 of Set 7 | ciamis
# Processing Record 16 of Set 7 | kenai
# Processing Record 17 of Set 7 | tukrah
# Processing Record 18 of Set 7 | yining
# Processing Record 19 of Set 7 | faanui
# Processing Record 20 of Set 7 | noyabrsk
# Processing Record 21 of Set 7 | seoul
# Processing Record 22 of Set 7 | yumen
# Processing Record 23 of Set 7 | heidelberg
# Processing Record 24 of Set 7 | yerbogachen
# Processing Record 25 of Set 7 | leningradskiy
# Processing Record 26 of Set 7 | boyolangu
# Processing Record 27 of Set 7 | yibin
# Processing Record 28 of Set 7 | batagay-alyta
# Processing Record 29 of Set 7 | sisimiut
# Processing Record 30 of Set 7 | alice springs
# Processing Record 31 of Set 7 | abaza
# Processing Record 32 of Set 7 | viedma
# Processing Record 33 of Set 7 | oranjestad
# Processing Record 34 of Set 7 | beringovskiy
# Processing Record 35 of Set 7 | ranong
# Processing Record 36 of Set 7 | fujin
# Processing Record 37 of Set 7 | linxia
# Processing Record 38 of Set 7 | bairiki
# Processing Record 39 of Set 7 | yulara
# Processing Record 40 of Set 7 | uvat
# Processing Record 41 of Set 7 | kavaratti
# Processing Record 42 of Set 7 | sabalgarh
# Processing Record 43 of Set 7 | san quintin
# Processing Record 44 of Set 7 | myitkyina
# Processing Record 45 of Set 7 | kawalu
# Processing Record 46 of Set 7 | bowen
# Processing Record 47 of Set 7 | claresholm
# Processing Record 48 of Set 7 | aklavik
# Processing Record 49 of Set 7 | hualmay
# Processing Record 50 of Set 7 | ronne
# Processing Record 1 of Set 8 | ntoum
# Processing Record 2 of Set 8 | ozernovskiy
# Processing Record 3 of Set 8 | ho chi minh city
# Processing Record 4 of Set 8 | umm jarr
# City not found. Skipping...
# Processing Record 5 of Set 8 | shimoda
# Processing Record 6 of Set 8 | mohan
# Processing Record 7 of Set 8 | basoko
# Processing Record 8 of Set 8 | mangrol
# Processing Record 9 of Set 8 | bitung
# Processing Record 10 of Set 8 | saint-pierre
# Processing Record 11 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 12 of Set 8 | sabya
# Processing Record 13 of Set 8 | nishihara
# Processing Record 14 of Set 8 | riyadh
# Processing Record 15 of Set 8 | kamaishi
# Processing Record 16 of Set 8 | ondjiva
# Processing Record 17 of Set 8 | lata
# Processing Record 18 of Set 8 | poronaysk
# Processing Record 19 of Set 8 | faya
# Processing Record 20 of Set 8 | bilibino
# Processing Record 21 of Set 8 | maner
# Processing Record 22 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 8 | teguise
# Processing Record 24 of Set 8 | le mars
# Processing Record 25 of Set 8 | talnakh
# Processing Record 26 of Set 8 | bay roberts
# Processing Record 27 of Set 8 | mehamn
# Processing Record 28 of Set 8 | paso de carrasco
# Processing Record 29 of Set 8 | sao miguel do araguaia
# Processing Record 30 of Set 8 | abay
# Processing Record 31 of Set 8 | umm kaddadah
# Processing Record 32 of Set 8 | roma
# Processing Record 33 of Set 8 | amnat charoen
# Processing Record 34 of Set 8 | chara
# Processing Record 35 of Set 8 | ixtapa
# Processing Record 36 of Set 8 | guasdualito
# Processing Record 37 of Set 8 | sao joao da barra
# Processing Record 38 of Set 8 | san cristobal
# Processing Record 39 of Set 8 | yasnyy
# Processing Record 40 of Set 8 | burnie
# Processing Record 41 of Set 8 | houma
# Processing Record 42 of Set 8 | mossendjo
# Processing Record 43 of Set 8 | erdenet
# Processing Record 44 of Set 8 | aneho
# Processing Record 45 of Set 8 | bengkulu
# Processing Record 46 of Set 8 | kautokeino
# Processing Record 47 of Set 8 | talakan
# Processing Record 48 of Set 8 | weinan
# Processing Record 49 of Set 8 | torbay
# Processing Record 50 of Set 8 | havelock
# Processing Record 1 of Set 9 | kluang
# Processing Record 2 of Set 9 | baykit
# Processing Record 3 of Set 9 | ukiah
# Processing Record 4 of Set 9 | antofagasta
# Processing Record 5 of Set 9 | amazar
# Processing Record 6 of Set 9 | byron bay
# Processing Record 7 of Set 9 | herat
# Processing Record 8 of Set 9 | bahia blanca
# Processing Record 9 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 9 | tual
# Processing Record 11 of Set 9 | miri
# Processing Record 12 of Set 9 | zhaotong
# Processing Record 13 of Set 9 | garm
# City not found. Skipping...
# Processing Record 14 of Set 9 | tura
# Processing Record 15 of Set 9 | ulladulla
# Processing Record 16 of Set 9 | port blair
# Processing Record 17 of Set 9 | nueva loja
# Processing Record 18 of Set 9 | soloneshnoye
# Processing Record 19 of Set 9 | aktash
# Processing Record 20 of Set 9 | ahuimanu
# Processing Record 21 of Set 9 | estelle
# Processing Record 22 of Set 9 | vardo
# Processing Record 23 of Set 9 | zvecka
# Processing Record 24 of Set 9 | meulaboh
# Processing Record 25 of Set 9 | san vicente
# Processing Record 26 of Set 9 | zaysan
# Processing Record 27 of Set 9 | dingle
# Processing Record 28 of Set 9 | celestun
# Processing Record 29 of Set 9 | mastic beach
# Processing Record 30 of Set 9 | northam
# Processing Record 31 of Set 9 | eyl
# Processing Record 32 of Set 9 | taoudenni
# Processing Record 33 of Set 9 | hailar
# Processing Record 34 of Set 9 | kayanga
# Processing Record 35 of Set 9 | chuy
# Processing Record 36 of Set 9 | powell
# Processing Record 37 of Set 9 | mankono
# Processing Record 38 of Set 9 | quchan
# Processing Record 39 of Set 9 | pella
# Processing Record 40 of Set 9 | freiberg
# Processing Record 41 of Set 9 | nouadhibou
# Processing Record 42 of Set 9 | lujiang
# Processing Record 43 of Set 9 | pitkyaranta
# Processing Record 44 of Set 9 | roros
# Processing Record 45 of Set 9 | nador
# Processing Record 46 of Set 9 | nelson bay
# Processing Record 47 of Set 9 | lebu
# Processing Record 48 of Set 9 | mogadishu
# Processing Record 49 of Set 9 | ampanihy
# Processing Record 50 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 10 | san jose
# Processing Record 2 of Set 10 | wana
# Processing Record 3 of Set 10 | puerto leguizamo
# Processing Record 4 of Set 10 | olafsvik
# Processing Record 5 of Set 10 | najran
# Processing Record 6 of Set 10 | velka bites
# Processing Record 7 of Set 10 | kruisfontein
# Processing Record 8 of Set 10 | george town
# Processing Record 9 of Set 10 | buta
# Processing Record 10 of Set 10 | dunedin
# Processing Record 11 of Set 10 | abu samrah
# Processing Record 12 of Set 10 | kamina
# Processing Record 13 of Set 10 | pierre
# Processing Record 14 of Set 10 | shingu
# Processing Record 15 of Set 10 | batemans bay
# Processing Record 16 of Set 10 | severo-kurilsk
# Processing Record 17 of Set 10 | gamba
# Processing Record 18 of Set 10 | paamiut
# Processing Record 19 of Set 10 | kapustin yar
# Processing Record 20 of Set 10 | moramanga
# Processing Record 21 of Set 10 | dezful
# Processing Record 22 of Set 10 | fairbanks
# Processing Record 23 of Set 10 | amberieu-en-bugey
# Processing Record 24 of Set 10 | tucurui
# Processing Record 25 of Set 10 | yabrud
# Processing Record 26 of Set 10 | ponta delgada
# Processing Record 27 of Set 10 | kokkola
# Processing Record 28 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 10 | nyrob
# Processing Record 30 of Set 10 | port hardy
# Processing Record 31 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 10 | plettenberg bay
# Processing Record 33 of Set 10 | dharchula
# Processing Record 34 of Set 10 | sistranda
# Processing Record 35 of Set 10 | abnub
# Processing Record 36 of Set 10 | goulburn
# Processing Record 37 of Set 10 | kasane
# Processing Record 38 of Set 10 | vilyuysk
# Processing Record 39 of Set 10 | olinda
# Processing Record 40 of Set 10 | araouane
# Processing Record 41 of Set 10 | jaciara
# Processing Record 42 of Set 10 | bandarbeyla
# Processing Record 43 of Set 10 | hamilton
# Processing Record 44 of Set 10 | lamu
# Processing Record 45 of Set 10 | wad rawah
# Processing Record 46 of Set 10 | castro
# Processing Record 47 of Set 10 | monrovia
# Processing Record 48 of Set 10 | biak
# Processing Record 49 of Set 10 | ust-ishim
# Processing Record 50 of Set 10 | naberera
# Processing Record 1 of Set 11 | genhe
# Processing Record 2 of Set 11 | chala
# Processing Record 3 of Set 11 | zinder
# Processing Record 4 of Set 11 | sandnessjoen
# Processing Record 5 of Set 11 | stulovo
# Processing Record 6 of Set 11 | moron
# Processing Record 7 of Set 11 | salekhard
# Processing Record 8 of Set 11 | mujiayingzi
# Processing Record 9 of Set 11 | inza
# Processing Record 10 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 11 of Set 11 | munster
# Processing Record 12 of Set 11 | victor harbor
# Processing Record 13 of Set 11 | chilpancingo
# Processing Record 14 of Set 11 | dandong
# Processing Record 15 of Set 11 | bereda
# Processing Record 16 of Set 11 | belfast
# Processing Record 17 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 19 of Set 11 | santa isabel
# Processing Record 20 of Set 11 | kununurra
# Processing Record 21 of Set 11 | olga
# Processing Record 22 of Set 11 | kumbo
# Processing Record 23 of Set 11 | novyy urengoy
# Processing Record 24 of Set 11 | lagoa
# Processing Record 25 of Set 11 | ola
# Processing Record 26 of Set 11 | nuuk
# Processing Record 27 of Set 11 | tarbes
# Processing Record 28 of Set 11 | tromso
# Processing Record 29 of Set 11 | tupi paulista
# Processing Record 30 of Set 11 | ca mau
# Processing Record 31 of Set 11 | khani
# Processing Record 32 of Set 11 | princeton
# Processing Record 33 of Set 11 | christchurch
# Processing Record 34 of Set 11 | arawa
# Processing Record 35 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 36 of Set 11 | itacoatiara
# Processing Record 37 of Set 11 | havre
# Processing Record 38 of Set 11 | north bend
# Processing Record 39 of Set 11 | klaksvik
# Processing Record 40 of Set 11 | tigil
# Processing Record 41 of Set 11 | lodeynoye pole
# Processing Record 42 of Set 11 | nuevo progreso
# Processing Record 43 of Set 11 | korla
# Processing Record 44 of Set 11 | karratha
# Processing Record 45 of Set 11 | ewa beach
# Processing Record 46 of Set 11 | panguna
# Processing Record 47 of Set 11 | ahipara
# Processing Record 48 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 11 | portland
# Processing Record 50 of Set 11 | lodwar
# Processing Record 1 of Set 12 | springbok
# Processing Record 2 of Set 12 | garowe
# Processing Record 3 of Set 12 | siteki
# Processing Record 4 of Set 12 | muskegon
# Processing Record 5 of Set 12 | ponte nova
# Processing Record 6 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 7 of Set 12 | narasannapeta
# Processing Record 8 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 9 of Set 12 | nalut
# Processing Record 10 of Set 12 | fare
# Processing Record 11 of Set 12 | afyonkarahisar
# Processing Record 12 of Set 12 | iralaya
# Processing Record 13 of Set 12 | humberto de campos
# Processing Record 14 of Set 12 | bathsheba
# Processing Record 15 of Set 12 | peniche
# Processing Record 16 of Set 12 | san fernando
# Processing Record 17 of Set 12 | rincon
# Processing Record 18 of Set 12 | duku
# Processing Record 19 of Set 12 | methven
# Processing Record 20 of Set 12 | porgera
# Processing Record 21 of Set 12 | kungurtug
# Processing Record 22 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 12 | tyret pervaya
# Processing Record 24 of Set 12 | puerto rico
# Processing Record 25 of Set 12 | aitape
# Processing Record 26 of Set 12 | safaga
# Processing Record 27 of Set 12 | korenovsk
# Processing Record 28 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 12 | vila franca do campo
# Processing Record 30 of Set 12 | nabire
# Processing Record 31 of Set 12 | avera
# Processing Record 32 of Set 12 | bongued
# Processing Record 33 of Set 12 | tiznit
# Processing Record 34 of Set 12 | pacific grove
# Processing Record 35 of Set 12 | nyborg
# Processing Record 36 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 12 | arlit
# Processing Record 38 of Set 12 | keti bandar
# Processing Record 39 of Set 12 | ryotsu
# Processing Record 40 of Set 12 | oranjemund
# Processing Record 41 of Set 12 | alugan
# Processing Record 42 of Set 12 | hervey bay
# Processing Record 43 of Set 12 | turtas
# Processing Record 44 of Set 12 | tashla
# Processing Record 45 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 12 | iracoubo
# Processing Record 47 of Set 12 | honiara
# Processing Record 48 of Set 12 | yatou
# Processing Record 49 of Set 12 | high level
# Processing Record 50 of Set 12 | iskateley
# Processing Record 1 of Set 13 | bolshaya dzhalga
# Processing Record 2 of Set 13 | sao jose da coroa grande
# Processing Record 3 of Set 13 | tjome
# Processing Record 4 of Set 13 | ereymentau
# Processing Record 5 of Set 13 | yarada
# Processing Record 6 of Set 13 | sioux lookout
# Processing Record 7 of Set 13 | zaria
# Processing Record 8 of Set 13 | pasni
# Processing Record 9 of Set 13 | sur
# Processing Record 10 of Set 13 | mosetse
# Processing Record 11 of Set 13 | bethanien
# Processing Record 12 of Set 13 | maraa
# Processing Record 13 of Set 13 | atar
# Processing Record 14 of Set 13 | lucapa
# Processing Record 15 of Set 13 | carangola
# Processing Record 16 of Set 13 | mayor pablo lagerenza
# Processing Record 17 of Set 13 | oeiras
# Processing Record 18 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 13 | fayaoue
# Processing Record 20 of Set 13 | nortelandia
# Processing Record 21 of Set 13 | husavik
# Processing Record 22 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 13 | vestmannaeyjar
# Processing Record 24 of Set 13 | meadow lake
# Processing Record 25 of Set 13 | coracora
# Processing Record 26 of Set 13 | coronado
# Processing Record 27 of Set 13 | san carlos de bariloche
# Processing Record 28 of Set 13 | rapar
# Processing Record 29 of Set 13 | siverek
# Processing Record 30 of Set 13 | chiredzi
# Processing Record 31 of Set 13 | pechenga
# Processing Record 32 of Set 13 | yenagoa
# Processing Record 33 of Set 13 | nekhayevskiy
# Processing Record 34 of Set 13 | okhotsk
# Processing Record 35 of Set 13 | isiro
# Processing Record 36 of Set 13 | rapid valley
# Processing Record 37 of Set 13 | peski
# Processing Record 38 of Set 13 | jubayl
# City not found. Skipping...
# Processing Record 39 of Set 13 | srednekolymsk
# Processing Record 40 of Set 13 | kpandae
# Processing Record 41 of Set 13 | general pico
# Processing Record 42 of Set 13 | eydhafushi
# Processing Record 43 of Set 13 | svetlyy
# Processing Record 44 of Set 13 | boa vista
# Processing Record 45 of Set 13 | selma
# Processing Record 46 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 47 of Set 13 | southbridge
# Processing Record 48 of Set 13 | glendive
# Processing Record 49 of Set 13 | vao
# Processing Record 50 of Set 13 | goderich
# Processing Record 1 of Set 14 | jalu
# Processing Record 2 of Set 14 | qobustan
# Processing Record 3 of Set 14 | mildura
# Processing Record 4 of Set 14 | hokitika
# Processing Record 5 of Set 14 | salym
# Processing Record 6 of Set 14 | kahului
# Processing Record 7 of Set 14 | kodinsk
# Processing Record 8 of Set 14 | ginir
# Processing Record 9 of Set 14 | poum
# Processing Record 10 of Set 14 | haines junction
# Processing Record 11 of Set 14 | baie-comeau
# Processing Record 12 of Set 14 | vila praia de ancora
# Processing Record 13 of Set 14 | college
# Processing Record 14 of Set 14 | broken hill
# Processing Record 15 of Set 14 | oda
# Processing Record 16 of Set 14 | padang
# Processing Record 17 of Set 14 | lima
# Processing Record 18 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 19 of Set 14 | lichinga
# Processing Record 20 of Set 14 | multan
# Processing Record 21 of Set 14 | nioro
# Processing Record 22 of Set 14 | umbuzeiro
# Processing Record 23 of Set 14 | grindavik
# Processing Record 24 of Set 14 | katherine
# Processing Record 25 of Set 14 | sitka
# Processing Record 26 of Set 14 | lieksa
# Processing Record 27 of Set 14 | waitati
# Processing Record 28 of Set 14 | tatawin
# Processing Record 29 of Set 14 | marienburg
# Processing Record 30 of Set 14 | wattegama
# Processing Record 31 of Set 14 | makung
# City not found. Skipping...
# Processing Record 32 of Set 14 | akdepe
# Processing Record 33 of Set 14 | santa cruz de la palma
# Processing Record 34 of Set 14 | prince rupert
# Processing Record 35 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 14 | tanete
# Processing Record 37 of Set 14 | shirokiy
# Processing Record 38 of Set 14 | manzil jamil
# City not found. Skipping...
# Processing Record 39 of Set 14 | cabedelo
# Processing Record 40 of Set 14 | nagato
# Processing Record 41 of Set 14 | serebryansk
# Processing Record 42 of Set 14 | aksu
# Processing Record 43 of Set 14 | igboho
# Processing Record 44 of Set 14 | kirksville
# Processing Record 45 of Set 14 | doha
# Processing Record 46 of Set 14 | ransang
# Processing Record 47 of Set 14 | opunake
# Processing Record 48 of Set 14 | brunswick
# Processing Record 49 of Set 14 | paraiso
# Processing Record 50 of Set 14 | laguna
# Processing Record 1 of Set 15 | edd
# Processing Record 2 of Set 15 | constitucion
# Processing Record 3 of Set 15 | stettler
# Processing Record 4 of Set 15 | ciudad bolivar
# Processing Record 5 of Set 15 | orichi
# Processing Record 6 of Set 15 | shieli
# Processing Record 7 of Set 15 | hammerfest
# Processing Record 8 of Set 15 | lao cai
# Processing Record 9 of Set 15 | rafsanjan
# Processing Record 10 of Set 15 | verkhnyaya inta
# Processing Record 11 of Set 15 | methoni
# Processing Record 12 of Set 15 | lensk
# Processing Record 13 of Set 15 | bonavista
# Processing Record 14 of Set 15 | anjar
# Processing Record 15 of Set 15 | saint-francois
# Processing Record 16 of Set 15 | neiafu
# Processing Record 17 of Set 15 | sinjar
# Processing Record 18 of Set 15 | pauini
# Processing Record 19 of Set 15 | rosario
# Processing Record 20 of Set 15 | yangambi
# Processing Record 21 of Set 15 | altamira
# Processing Record 22 of Set 15 | kolobovo
# Processing Record 23 of Set 15 | san andres
# Processing Record 24 of Set 15 | samdari
# Processing Record 25 of Set 15 | menongue
# Processing Record 26 of Set 15 | chunoyar
# Processing Record 27 of Set 15 | kuusamo
# Processing Record 28 of Set 15 | palma
# Processing Record 29 of Set 15 | inuvik
# Processing Record 30 of Set 15 | burica
# City not found. Skipping...
# Processing Record 31 of Set 15 | pisco
# Processing Record 32 of Set 15 | fatehpur
# Processing Record 33 of Set 15 | elk point
# Processing Record 34 of Set 15 | boatlaname
# City not found. Skipping...
# Processing Record 35 of Set 15 | addis abeba
# Processing Record 36 of Set 15 | baihar
# Processing Record 37 of Set 15 | suzu
# City not found. Skipping...
# Processing Record 38 of Set 15 | parabel
# Processing Record 39 of Set 15 | vila velha
# Processing Record 40 of Set 15 | baruun-urt
# Processing Record 41 of Set 15 | micheweni
# Processing Record 42 of Set 15 | bedele
# Processing Record 43 of Set 15 | bandar-e lengeh
# Processing Record 44 of Set 15 | willowmore
# Processing Record 45 of Set 15 | igarka
# Processing Record 46 of Set 15 | jiaozhou
# Processing Record 47 of Set 15 | mesto albrechtice
# Processing Record 48 of Set 15 | verkhnyaya salda
# Processing Record 49 of Set 15 | asau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 693

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Zheshart  62.0731   49.5733     37.42        99         100
# 1           Anshun  26.2500  105.9333     67.50        54           0
# 2          Ushuaia -54.8000  -68.3000     37.06        87          75
# 3         Tasiilaq  65.6145  -37.6368     21.27        88         100
# 4          Socorro  31.6546 -106.3033     72.59        26          14
# 5            Wuwei  37.9281  102.6414     47.48        29         100
# 6           Albany  42.6001  -73.9662     48.92        48          86
# 7  Bambous Virieux -20.3428   57.7575     79.21        88          75
# 8       Chokurdakh  70.6333  147.9167      6.75        85         100
# 9           Noumea -22.2763  166.4572     85.98        74          15
#
#    Wind Speed Country      Current Description                 Date
# 0        5.73      RU          overcast clouds  2022-04-13 03:55:53
# 1        7.78      CN                clear sky  2022-04-13 03:55:54
# 2       19.57      AR  light intensity drizzle  2022-04-13 03:55:23
# 3        7.20      GL               light snow  2022-04-13 03:55:54
# 4       30.53      US               few clouds  2022-04-13 03:55:55
# 5        4.34      CN          overcast clouds  2022-04-13 03:55:55
# 6        4.47      US          overcast clouds  2022-04-13 03:55:55
# 7       11.50      MU               light rain  2022-04-13 03:55:56
# 8        2.39      RU          overcast clouds  2022-04-13 03:51:07
# 9        7.27      NC               few clouds  2022-04-13 03:54:34

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity","Cloudiness", "Wind Speed", "Current Description"]

# %%
# Changing column order DataFrame.
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Zheshart      RU  62.0731   49.5733     37.42        99         100
# 1    Anshun      CN  26.2500  105.9333     67.50        54           0
# 2   Ushuaia      AR -54.8000  -68.3000     37.06        87          75
# 3  Tasiilaq      GL  65.6145  -37.6368     21.27        88         100
# 4   Socorro      US  31.6546 -106.3033     72.59        26          14
#
#    Wind Speed      Current Description
# 0        5.73          overcast clouds
# 1        7.78                clear sky
# 2       19.57  light intensity drizzle
# 3        7.20               light snow
# 4       30.53               few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df = pd.read_csv("Weather_Database/WeatherPy_Database.csv", index_col=None)
city_data_df
# Out:
#      City_ID               City Country      Lat       Lng  Max Temp  \
# 0          0           Zheshart      RU  62.0731   49.5733     37.42
# 1          1             Anshun      CN  26.2500  105.9333     67.50
# 2          2            Ushuaia      AR -54.8000  -68.3000     37.06
# 3          3           Tasiilaq      GL  65.6145  -37.6368     21.27
# 4          4            Socorro      US  31.6546 -106.3033     72.59
# ..       ...                ...     ...      ...       ...       ...
# 688      688             Igarka      RU  67.4667   86.5833     33.82
# 689      689           Jiaozhou      CN  36.2839  120.0033     60.76
# 690      690  Mesto Albrechtice      CZ  50.1629   17.5748     38.82
# 691      691   Verkhnyaya Salda      RU  58.0456   60.5533     41.52
# 692      692               Asau      RO  46.4333   26.4000     38.32
#
#      Humidity  Cloudiness  Wind Speed      Current Description
# 0          99         100        5.73          overcast clouds
# 1          54           0        7.78                clear sky
# 2          87          75       19.57  light intensity drizzle
# 3          88         100        7.20               light snow
# 4          26          14       30.53               few clouds
# ..        ...         ...         ...                      ...
# 688       100         100       11.50               light snow
# 689        24         100       11.45          overcast clouds
# 690        64           7        4.23                clear sky
# 691        71          76        5.39            broken clouds
# 692        83          17        5.41               few clouds
#
# [693 rows x 10 columns]
